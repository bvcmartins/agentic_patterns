# %%
from langchain_ollama import ChatOllama
from langchain import hub

# %%
llm = ChatOllama(model="llama4:scout", temperature=0)

# %%
llm.invoke("What is the capital of France?")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 llm.invoke("What is the capital of France?")
#
# File ~/anaconda3/envs/agentic_patterns/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)    367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File ~/anaconda3/envs/agentic_patterns/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)    954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/agentic_patterns/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File ~/anaconda3/envs/agentic_patterns/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/agentic_patterns/lib/python3.12/site-packages/langchain_ollama/chat_models.py:741, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     734 def _generate(
#     735     self,
#     736     messages: list[BaseMessage],
#    (...)    739     **kwargs: Any,
#     740 ) -> ChatResult:
# --> 741     final_chunk = self._chat_stream_with_aggregation(
#     742         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     743     )
#     744     generation_info = final_chunk.generation_info
#     745     chat_generation = ChatGeneration(
#     746         message=AIMessage(
#     747             content=final_chunk.text,
#    (...)    752         generation_info=generation_info,
#     753     )
#
# File ~/anaconda3/envs/agentic_patterns/lib/python3.12/site-packages/langchain_ollama/chat_models.py:678, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     669 def _chat_stream_with_aggregation(
#     670     self,
#     671     messages: list[BaseMessage],
#    (...)    675     **kwargs: Any,
#     676 ) -> ChatGenerationChunk:
#     677     final_chunk = None
# --> 678     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     679         if final_chunk is None:
#     680             final_chunk = chunk
#
# File ~/anaconda3/envs/agentic_patterns/lib/python3.12/site-packages/langchain_ollama/chat_models.py:763, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#     756 def _iterate_over_stream(
#     757     self,
#     758     messages: list[BaseMessage],
#     759     stop: Optional[list[str]] = None,
#     760     **kwargs: Any,
#     761 ) -> Iterator[ChatGenerationChunk]:
#     762     is_thinking = False
# --> 763     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     764         if not isinstance(stream_resp, str):
#     765             if stream_resp.get("done") is True:
#
# File ~/anaconda3/envs/agentic_patterns/lib/python3.12/site-packages/langchain_ollama/chat_models.py:665, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     662 chat_params = self._chat_params(messages, stop, **kwargs)
#     664 if chat_params["stream"]:
# --> 665     yield from self._client.chat(**chat_params)
#     666 else:
#     667     yield self._client.chat(**chat_params)
#
# File ~/anaconda3/envs/agentic_patterns/lib/python3.12/site-packages/ollama/_client.py:170, in Client._request.<locals>.inner()
#     168 except httpx.HTTPStatusError as e:
#     169   e.response.read()
# --> 170   raise ResponseError(e.response.text, e.response.status_code) from None
#     172 for line in r.iter_lines():
#     173   part = json.loads(line)
#
# ResponseError: model "llama4:scout" not found, try pulling it first (status code: 404)
