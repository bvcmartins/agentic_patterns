# %% [markdown]
# Source: https://levelup.gitconnected.com/building-a-training-architecture-for-self-improving-ai-agents-c87a4e316b22

# %% [markdown]
# ## SOP
#
# Standard Operating Procedure. Our planner agent will create a JSON-based SOP for our RAG agentic system, which defines how, when and what actions to take.
